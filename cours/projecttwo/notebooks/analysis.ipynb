# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("operations_enrichies.csv", parse_dates=[0])
data.head()
# Out:
#   date_operation                     libelle  montant  solde_avt_ope  \
# 0     2023-03-31    DON XX XX XX XX XX XX XX    -1.44        1515.25
# 1     2023-04-03         CARTE XX XX RAPT XX   -24.00        1513.81
# 2     2023-04-03         CARTE XX XX RAPT XX   -73.00        1489.81
# 3     2023-04-03           CARTE XX XX XX XX   -14.39        1416.81
# 4     2023-04-03  VIREMENT XX XX XX XX XX XX     4.80        1402.42
#
#        categ      type    tranche_depense    sens  annee  mois  jour  \
# 0      AUTRE       DON             petite   debit   2023     3    31
# 1  TRANSPORT     CARTE             petite   debit   2023     4     3
# 2  TRANSPORT     CARTE             petite   debit   2023     4     3
# 3      AUTRE     CARTE             petite   debit   2023     4     3
# 4      AUTRE  VIREMENT  (pas une dépense)  credit   2023     4     3
#
#                                             jour_sem  jour_sem_num  weekend  \
# ...

# %%
data["categ"]
# Out:
# 0                    AUTRE
# 1                TRANSPORT
# 2                TRANSPORT
# 3                    AUTRE
# 4                    AUTRE
#               ...
# 303                  AUTRE
# 304                  AUTRE
# 305      FACTURE TELEPHONE
# 306             RESTAURANT
# 307    COTISATION BANCAIRE
# Name: categ, Length: 308, dtype: object

# %%
data["categ"].value_counts()
# Out:
# AUTRE                  212
# COURSES                 39
# TRANSPORT               21
# RESTAURANT              16
# FACTURE TELEPHONE        7
# COTISATION BANCAIRE      7
# LOYER                    6
# Name: categ, dtype: int64

# %%
# VARIABLE QUALITATIVE
# Diagramme en secteurs
data["categ"].value_counts(normalize=True).plot(kind='pie')
# Cette ligne assure que le pie chart est un cercle plutôt qu'une éllipse
plt.axis('equal') 
plt.show() # Affiche le graphique

# %%
# Diagramme en tuyaux d'orgues
data["categ"].value_counts(normalize=True).plot(kind='bar')
plt.show()

# %%
# VARIABLE QUANTITATIVE
# Diagramme en bâtons
data["quart_mois"].value_counts(normalize=True).plot(kind='bar',width=0.1)
plt.show()

# %%
# Histogramme
data["montant"].hist(density=True)
plt.show()

# %%
# Histogramme plus beau
data[data.montant.abs() < 100]["montant"].hist(density=True,bins=20)
plt.show()

# %%
data.head()
# Out:
#   date_operation                     libelle  montant  solde_avt_ope  \
# 0     2023-03-31    DON XX XX XX XX XX XX XX    -1.44        1515.25
# 1     2023-04-03         CARTE XX XX RAPT XX   -24.00        1513.81
# 2     2023-04-03         CARTE XX XX RAPT XX   -73.00        1489.81
# 3     2023-04-03           CARTE XX XX XX XX   -14.39        1416.81
# 4     2023-04-03  VIREMENT XX XX XX XX XX XX     4.80        1402.42
#
#        categ      type    tranche_depense    sens  annee  mois  jour  \
# 0      AUTRE       DON             petite   debit   2023     3    31
# 1  TRANSPORT     CARTE             petite   debit   2023     4     3
# 2  TRANSPORT     CARTE             petite   debit   2023     4     3
# 3      AUTRE     CARTE             petite   debit   2023     4     3
# 4      AUTRE  VIREMENT  (pas une dépense)  credit   2023     4     3
#
#                                             jour_sem  jour_sem_num  weekend  \
# ...

# %%
# la moyenne
data['montant'].mean()
# Out:
# 2.872564935064936

# %%
#  la médiane
data['montant'].median()
# Out:
# -9.6

# %%
# Le mode
data['montant'].mode()
# Out:
# 0   -1.6
# dtype: float64

# %%
for cat in data["categ"].unique():
    subset = data[data.categ == cat] # Création du sous-échantillon
    print("-"*20)
    print(cat)
    print("moy:\n",subset['montant'].mean())
    print("med:\n",subset['montant'].median())
    print("mod:\n",subset['montant'].mode())
    subset["montant"].hist() # Crée l'histogramme
    plt.show() # Affiche l'histogramme
# Out:
# --------------------
# AUTRE
# moy:
#  23.43320754716981
# med:
#  -8.31
# mod:
#  0   -1.6
# dtype: float64
# --------------------
# TRANSPORT
# moy:
#  -52.99714285714286
# med:
#  -53.1
# mod:
#  0   -73.0
# dtype: float64
# --------------------
# FACTURE TELEPHONE
# moy:
#  -12.045714285714283
# med:
#  -7.02
# mod:
#  0   -7.02
# 1   -6.38
# dtype: float64
# --------------------
# COURSES
# moy:
#  -16.341282051282054
# med:
#  -12.24
# mod:
#  0    -60.16
# 1    -42.45
# 2    -42.42
# 3    -33.55
# 4    -32.67
# 5    -29.18
# 6    -28.11
# 7    -27.68
# 8    -26.58
# 9    -26.19
# 10   -23.43
# 11   -22.59
# 12   -21.73
# 13   -20.59
# 14   -18.45
# 15   -17.16
# 16   -13.59
# 17   -12.96
# 18   -12.49
# 19   -12.24
# 20   -10.91
# 21   -10.36
# 22    -9.88
# 23    -9.60
# 24    -9.31
# 25    -9.11
# 26    -6.89
# 27    -6.80
# 28    -6.60
# 29    -5.88
# 30    -4.63
# 31    -4.41
# 32    -4.39
# 33    -3.48
# 34    -2.93
# 35    -2.56
# 36    -2.51
# 37    -1.90
# 38    -0.94
# ...

# %%
a = pd.DataFrame(
    { "temp" : [70, 60, 50, 55, 55, 65, 65]
})
a["temp"].mean()
# Out:
# 60.0

# %%
a["temp"].mode()
# Out:
# 0    55
# 1    65
# dtype: int64

# %%
a["temp"].median()
# Out:
# 60.0

# %%
for cat in data["categ"].unique():
    subset = data[data.categ == cat]
    print("-"*20)
    print(cat)
    print("moy:\n",subset['montant'].mean())
    print("med:\n",subset['montant'].median())
    print("mod:\n",subset['montant'].mode())
    print("var:\n",subset['montant'].var(ddof=0)) # La variance
    print("ect:\n",subset['montant'].std(ddof=0)) # L'écart-type
    subset["montant"].hist()
    plt.show()
    subset.boxplot(column="montant", vert=False)
    plt.show()
# Out:
# --------------------
# AUTRE
# moy:
#  23.43320754716981
# med:
#  -8.31
# mod:
#  0   -1.6
# dtype: float64
# var:
#  40401.82999254183
# ect:
#  201.00206464746034
# --------------------
# TRANSPORT
# moy:
#  -52.99714285714286
# med:
#  -53.1
# mod:
#  0   -73.0
# dtype: float64
# var:
#  2205.016868027212
# ect:
#  46.95760713694014
# --------------------
# FACTURE TELEPHONE
# moy:
#  -12.045714285714283
# med:
#  -7.02
# mod:
#  0   -7.02
# 1   -6.38
# dtype: float64
# var:
#  105.01905306122445
# ect:
#  10.247880417980317
# --------------------
# COURSES
# moy:
#  -16.341282051282054
# med:
#  -12.24
# mod:
#  0    -60.16
# 1    -42.45
# 2    -42.42
# 3    -33.55
# 4    -32.67
# 5    -29.18
# 6    -28.11
# 7    -27.68
# 8    -26.58
# 9    -26.19
# 10   -23.43
# 11   -22.59
# 12   -21.73
# 13   -20.59
# 14   -18.45
# 15   -17.16
# 16   -13.59
# 17   -12.96
# 18   -12.49
# 19   -12.24
# 20   -10.91
# 21   -10.36
# 22    -9.88
# 23    -9.60
# 24    -9.31
# 25    -9.11
# ...

# %%
test = pd.DataFrame({
    "valeurs" : [1,10,1,10,1,1,5,1,5,5]
})

# %%
print("la moyenne: ", test["valeurs"].mean())
print("Le mode: ", test["valeurs"].mode())
print("La médiane: ", test["valeurs"].median())
# Out:
# la moyenne:  4.0
# Le mode:  0    1
# dtype: int64
# La médiane:  3.0

# %%
Test_A = pd.DataFrame({
    "valeurs" : [6,4,6,4,6,4,6,4]
})
Test_B = pd.DataFrame({
    "valeurs" : [1,4,1,4,1,4,1,4]
})
print("la variance : ", Test_A["valeurs"].var())
print("la variance : ", Test_B["valeurs"].var())
# Out:
# la variance :  1.1428571428571428
# la variance :  2.5714285714285716

# %%
for cat in data["categ"].unique():
    subset = data[data.categ == cat]
    print("-"*20)
    print(cat)
    print("moy:\n",subset['montant'].mean())
    print("med:\n",subset['montant'].median())
    print("mod:\n",subset['montant'].mode())
    print("var:\n",subset['montant'].var(ddof=0)) # La variance
    print("ect:\n",subset['montant'].std(ddof=0)) # L'écart-type
    print("skw:\n",subset['montant'].skew()) # Le Skewness 
    print("kur:\n",subset['montant'].kurtosis()) # Le Kurtosis
    subset["montant"].hist()
    plt.show()
    subset.boxplot(column="montant", vert=False)
    plt.show()

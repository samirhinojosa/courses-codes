# %%
""" 
The Monty Hall problem
https://en.wikipedia.org/wiki/Monty_Hall_problem 

"""
import matplotlib.pyplot as plt
from helpers import Strategy, play, play_with_numpy

# %%
sum(play(Strategy.CHANGE, 1000))
# Out:
# 500

# %%
change_player_gains, keep_player_gains = play_with_numpy(1000)
print("The result of win based on door change is:", sum(change_player_gains))
print("The result of win based on door keep is: {}" .format(sum(keep_player_gains)))
# Out:
# The result of win based on door change is: 691
# The result of win based on door keep is: 309

# %%
plot = plt.bar([1,2], [sum(change_player_gains)/1000, sum(keep_player_gains)/1000], tick_label=["Change","Keep"])
